# %% [markdown]
# # Data Rangers
# Taller de Visualización y Análisis de Datos 101
# by Fernanda Ochoa

# %% [markdown]
# ### Importamos las herramientas
#
# Para este lab requerimos de las siguientes bibliotecas:
#
#
#
# *   Numpy
#     + Es una biblioteca que proporciona toda la utileria necesaria para realizar Cómputo Científico.
#     + Su dominio principal es el Álgebra Lineal, Transformadas de Fourier y Matrices.
#     + [NumpyDocs](https://numpy.org/)
# *   Pandas
#     + Es una biblioteca considerada extensión de Numpy para la manipulación y análisis de datos con Python.
#     + [Pandas Doc](https://pandas.pydata.org/)
# *   Matplotlib
#     + Es una biblioteca para la generación de gráficos a partir de datos contenidos en listas o arreglos con python.
#     + [Matplotlib Docs](https://matplotlib.org/stable/index.html)
# *   Seaborn
#     + Es una biblioteca que extiende la funcionalidad de Matplotlib y permite generar diferentes tipos de gráficos.
#     + [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# ### Preparamos el entorno de trabajo, instalando los paquetes necesarios.

# %%
# Pandas, Matplotlib, Numpy y Seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Cargamos el dataset que vamos a utilizar
#
# Si estás en GColab/Azure Notebooks es importante que agregues el dataset
#
# El formato del dataset de preferencia sea un .csv
#
# ##### Pasos para cargar un dataset
#
# * Crear una variable que almacene la ruta del dataset
# * Creamos una variable que contenga el dataset en un dataframe, primero leemos el dataset y después lo almacenamos en la variable

# %%
fifa_filepath = './fifa.csv'
fifa_data = pd.read_csv(fifa_filepath, index_col='Date', parse_dates=True)

# %% [markdown]
# Verificamos el dataset
#
# Llamamos a la función head y le pedimos que imprima los primeros 10 registros del dataset

# %%
fifa_data.head(10)
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# 1994-02-15   9.0  2.0   6.0  14.0  1.0   7.0
# 1994-03-15   8.0  2.0   6.0  15.0  1.0  11.0
# 1994-04-19  10.0  1.0   7.0  15.0  2.0  13.0
# 1994-05-17   6.0  1.0   9.0  17.0  2.0  16.0
# 1994-06-14   8.0  3.0   5.0  13.0  1.0   4.0

# %% [markdown]
# ### ¿Cuántos registros tiene el dataset?

# %%
fifa_data.shape[0]
# Out:
# 286

# %% [markdown]
# ### Obteniendo información detallada de nuestro dataset

# %%
fifa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 286 entries, 1993-08-08 to 2018-06-07
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ARG     286 non-null    float64
#  1   BRA     286 non-null    float64
#  2   ESP     286 non-null    float64
#  3   FRA     286 non-null    float64
#  4   GER     286 non-null    float64
#  5   ITA     286 non-null    float64
# dtypes: float64(6)
# memory usage: 15.6 KB

# %% [markdown]
# ### ¿Cuántas columnas tiene el dataset?

# %%
fifa_data.shape[1]
# Out:
# 6

# %% [markdown]
# ### Imprime el nombre de todas las columnas

# %%
fifa_data.columns
# Out:
# Index(['ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA'], dtype='object')

# %% [markdown]
# #### Visualización de los datos

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa_data)

# %% [markdown]
# # Museos
#
# En este ejercicio, utilizaremos los conceptos anteriores para proponer una solución a un escenario real.
#
# Para ello debemos:
#
# * Importar las bibliotecas necesarias
# * Importar el dataset
# * Entender y Conocer nuestro dataset
# * Responder preguntas utilizando los datos
# * Generar un gráfico para entener los patrones

# %% [markdown]
# ## Esenario
# Recientemente, has sido contratado para administrar los museos de la ciudad de Los Ángeles, Ca. Tu primer proyecto se centra en los cuatros museos que te muestro a continuación.
#
# ![Museos](https://camo.githubusercontent.com/1c9a804d63220d81f0b41da90d97667873e2ac84/68747470733a2f2f692e696d6775722e636f6d2f7046594c384a312e706e67)
#
# Para ello, aprovecharemos los datos que proporciona el portal de Datos Abiertos de la ciudad de [Los Ángeles](https://data.lacity.org/) de [forma mensual](https://data.lacity.org/Arts-Culture/Museum-Visitors/trxm-jn3c)

# %% [markdown]
# ### Preparamos el entorno

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('Setup Completo')
# Out:
# Setup Completo

# %% [markdown]
# ### Cargamos los datos
#
# Lo primero que debemos hacer es leer el archivo de datos de visitantes del museo de Los Ángeles en museum_data. Teniendo en cuenta que:
#
# La ruta del archivo al conjunto de datos se almacena como museum_filepath
#
# El nombre de la columna que se utilizará como etiqueta de fila es 'Fecha'
#
# Ejemplo de como se carga un dataset
#
#
#
# ```
# # Ruta del archivo/dataset a utilizar
# dataset_filepath = './dataset.csv'
#
# # Leemos y almacenamos el archivo en un dataframe
# dataset_data = pd.read_csv(dataset_filepath, index_col='Date', parse_date='True')
#
# ```

# %%
# Ruta del archivo/dataset a utilizar
museum_filepath = './museum_visitors.csv'

museum_data = pd.read_csv(museum_filepath, index_col='Date', parse_dates=True)

# %% [markdown]
# ### Revisamos nuestro dataset
# Utilizaremos el comando de Python tail(), que nos permite imprimir las últimas 5 filas de datos en el dataset.

# %%
museum_data.tail()
# Out:
#             Avila Adobe  ...  America Tropical Interpretive Center
# Date                     ...
# 2018-07-01        23136  ...                                  4718
# 2018-08-01        20815  ...                                  3891
# 2018-09-01        21020  ...                                  3180
# 2018-10-01        19280  ...                                  3775
# 2018-11-01        17163  ...                                  4562
#
# [5 rows x 4 columns]

# %% [markdown]
# La última fila (para 2018-11-01) rastrea la cantidad de visitantes a cada museo en noviembre de 2018, la penúltima fila (para 2018-10-01) rastrea la cantidad de visitantes a cada museo en octubre de 2018, etcétera.
#
# Utilizaremos las últimas 5 filas de los datos para responder las siguientes preguntas.
#
# ¿Cuántos visitantes recibió el Museo Chino Americano en julio de 2018?
#   ca_museum_jul18 = 2620
#
# En octubre de 2018, ¿cuántos visitantes más recibió Ávila Adobe que el Museo Firehouse?
#   avila_oct18 = 14658

# %% [markdown]
# ## Convenciendo a la junta del museo
# El Museo de la Casa de Bomberos afirma que organizó un evento en 2014 que atrajo una cantidad increíble de visitantes y que deberían obtener un presupuesto adicional para realizar un evento similar nuevamente. Los otros museos piensan que este tipo de eventos no son tan importantes, y los presupuestos deben dividirse exclusivamente en función de los visitantes recientes en un día promedio.
#
# Para mostrarle al tablero del museo cómo se comparó el evento con el tráfico regular en cada museo, debemos crear un gráfico de líneas que muestre cómo evolucionó el número de visitantes de cada museo con el tiempo.
#
# La figura debe tener cuatro líneas (una para cada museo).

# %%
sns.lineplot(data=museum_data)

# %% [markdown]
# ## Evaluando la Estacionalidad
#
# Supongamos que nos reunimos con los empleados de Ávila Adobe, escuchando que uno de los principales puntos débiles es que el número de visitantes del museo varía mucho con las estaciones, con temporadas bajas (cuando los empleados están perfectamente dotados de personal y felices) y también temporadas altas (cuando los empleados tienen poco personal y están estresados). Nos damos cuenta de que si pudieramos predecir estas temporadas altas y bajas, podríamos planificar con anticipación la contratación de algunos empleados de temporada adicionales para ayudar con el trabajo adicional.
#
# Parte A
# Para resolver esto debemos crear un gráfico de líneas que muestre cómo ha evolucionado el número de visitantes de Ávila Adobe a lo largo del tiempo. (Si el código devuelve un error, lo primero que debe verificar es que hayas escrito correctamente el nombre de la columna. Debes escribir el nombre de la columna exactamente como aparece en el conjunto de datos).

# %%
# Listar las columnas
list(museum_data.columns)
# Out:
# ['Avila Adobe',
#  'Firehouse Museum',
#  'Chinese American Museum',
#  'America Tropical Interpretive Center']

# %%
# Gráfico de líneas que muestre el número de visitantes de Ávila Adobe a lo largo del tiempo

plt.figure(figsize=(12,6))
plt.title('Número de visitantes de Ávila Adobe a lo largo del tiempo')
sns.lineplot(data= museum_data['Avila Adobe'], label= 'Avila Adobe')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# Parte B
# ¿En qué temporada Avila Adobe recibe más visitantes?
#
# Entre septiembre-febrero (en Los Ángeles, los meses de otoño e invierno), o Entre marzo-agosto (en Los Ángeles, la primavera y el verano)? Con esta información, ¿Cuándo debería el personal del museo agregar empleos estacionales?

# %% [markdown]
# El gráfico generalmente desciende a valores relativamente bajos alrededor de la primera parte de cada año (en diciembre y enero) y alcanza sus valores más altos a mediados de año (especialmente alrededor de mayo y junio). Por lo tanto, Avila Adobe suele recibir más visitantes en marzo-agosto (o los meses de primavera y verano). Con esto en mente, Avila Adobe definitivamente podría beneficiarse de la contratación de más empleados de temporada para ayudar con el trabajo adicional en marzo-agosto (la primavera y el verano).
